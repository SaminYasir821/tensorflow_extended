# %%
import tensorflow_data_validation as tfdv
# Out:
# 2025-06-11 21:24:04.977390: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-06-11 21:24:04.988433: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-06-11 21:24:05.070511: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-06-11 21:24:05.170948: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:479] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# ...

# %%
stats = tfdv.generate_statistics_from_csv(data_location="/home/samin96/Data Ingestion with TFX/data2/iris.csv", delimiter=",")
stats
# Out:
# datasets {
#   num_examples: 150
#   features {
#     type: FLOAT
#     num_stats {
#       common_stats {
#         num_non_missing: 150
#         min_num_values: 1
#         max_num_values: 1
#         avg_num_values: 1.0
#         num_values_histogram {
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 15.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 15.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 15.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 15.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 15.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
# ...

# %%
schema = tfdv.infer_schema(stats)
schema
# Out:
# feature {
#   name: "sepal.length"
#   type: FLOAT
#   presence {
#     min_fraction: 1.0
#     min_count: 1
#   }
#   shape {
#     dim {
#       size: 1
#     }
#   }
# }
# feature {
#   name: "sepal.width"
#   type: FLOAT
#   presence {
#     min_fraction: 1.0
#     min_count: 1
#   }
#   shape {
#     dim {
#       size: 1
#     }
#   }
# }
# feature {
#   name: "petal.length"
#   type: FLOAT
#   presence {
#     min_fraction: 1.0
#     min_count: 1
#   }
#   shape {
#     dim {
#       size: 1
#     }
#   }
# }
# feature {
#   name: "petal.width"
#   type: FLOAT
#   presence {
#     min_fraction: 1.0
#     min_count: 1
#   }
#   shape {
#     dim {
#       size: 1
#     }
#   }
# }
# feature {
#   name: "variety"
#   type: BYTES
#   domain: "variety"
#   presence {
#     min_fraction: 1.0
#     min_count: 1
#   }
#   shape {
#     dim {
#       size: 1
#     }
#   }
# }
# string_domain {
#   name: "variety"
#   value: "Setosa"
#   value: "Versicolor"
#   value: "Virginica"
# }

# %%
tfdv.display_schema(schema)
# Out:
#                   Type  Presence Valency     Domain
# Feature name
# 'sepal.length'   FLOAT  required                  -
# 'sepal.width'    FLOAT  required                  -
# 'petal.length'   FLOAT  required                  -
# 'petal.width'    FLOAT  required                  -
# 'variety'       STRING  required          'variety'
#                                         Values
# Domain
# 'variety'  'Setosa', 'Versicolor', 'Virginica'

# %%
train_stats = tfdv.generate_statistics_from_csv(data_location="/home/samin96/Data Ingestion with TFX/data2/iris.csv", delimiter=",")
train_stats
# Out:
# datasets {
#   num_examples: 150
#   features {
#     type: FLOAT
#     num_stats {
#       common_stats {
#         num_non_missing: 150
#         min_num_values: 1
#         max_num_values: 1
#         avg_num_values: 1.0
#         num_values_histogram {
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 15.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 15.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 15.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 15.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 15.0
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
# ...

# %%
train_data = 'data_tfrecord-00000-of-00001.gz'
val_stats = tfdv.generate_statistics_from_tfrecord(data_location=train_data)
val_stats
# Out:
# datasets {
#   num_examples: 27
#   features {
#     type: FLOAT
#     num_stats {
#       common_stats {
#         num_non_missing: 27
#         min_num_values: 1
#         max_num_values: 1
#         avg_num_values: 1.0
#         num_values_histogram {
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 2.7
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 2.7
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 2.7
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 2.7
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
#             sample_count: 2.7
#           }
#           buckets {
#             low_value: 1.0
#             high_value: 1.0
# ...

# %%
tfdv.visualize_statistics(lhs_statistics=val_stats, rhs_statistics=train_stats, lhs_name="VAL_DATASET", rhs_name="TRAIN_DATASET")
# Out:
# <iframe id='facets-iframe' width="100%" height="500px"></iframe>
#         <script>
#         facets_iframe = document.getElementById('facets-iframe');
#         facets_html = '<script src="https://cdnjs.cloudflare.com/ajax/libs/webcomponentsjs/1.3.3/webcomponents-lite.js"><\/script><link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/master/facets-dist/facets-jupyter.html"><facets-overview proto-input="..."></facets-overview>';
#         facets_iframe.srcdoc = facets_html;
#          facets_iframe.id = "";
#          setTimeout(() => {
#            facets_iframe.setAttribute('height', facets_iframe.contentWindow.document.body.offsetHeight + 'px')
#          }, 1500)
#          </script>
